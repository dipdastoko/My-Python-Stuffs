# %%
#Sending Emails with Python

# %%
import smtplib

# %%
smtp_object = smtplib.SMTP('smtp.gmail.com')

# %%
smtp_object.ehlo()
# Out:
# (250,
#  b'smtp.gmail.com at your service, [119.148.56.202]\nSIZE 35882577\n8BITMIME\nSTARTTLS\nENHANCEDSTATUSCODES\nPIPELINING\nCHUNKING\nSMTPUTF8')

# %%
smtp_object.starttls()
# Out:
# (220, b'2.0.0 Ready to start TLS')

# %%
import getpass

# %%
email = getpass.getpass("Email :")
password = getpass.getpass("Pass: ")
smtp_object.login(email,password)
# Out:
# Email : ········
# Pass:  ········
# (235, b'2.7.0 Accepted')

# %%
from_address = email
to_address = email
subject = "Test Py Script"
message = "Sending Email through PyScript"
msg = "Subject: "+subject+'\n'+message

# %%
smtp_object.sendmail(from_address,to_address,msg)
# Out:
# {}

# %%
smtp_object.quit()
# Out:
# (221,
#  b'2.0.0 closing connection a92af1059eb24-13fca9111b6sm215625c88.13 - gsmtp')
