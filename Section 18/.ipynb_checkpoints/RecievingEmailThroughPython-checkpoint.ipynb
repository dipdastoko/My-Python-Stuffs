# %%
#Recieving Email Through Python

# %%
import imaplib
import email

# %%
M = imaplib.IMAP4_SSL('imap.gmail.com')

# %%
import getpass

# %%
email = getpass.getpass("Email: ")
password = getpass.getpass("Pass: ")
# Out:
# Email:  ········
# Pass:  ········

# %%
M.login(email,password)
# Out:
# ('OK', [b'classmaterialsaiub@gmail.com authenticated (Success)'])

# %%
M.select('inbox')
# Out:
# ('OK', [b'2887'])

# %%
M.list()
# Out:
# ('OK',
#  [b'(\\HasNoChildren) "/" "INBOX"',
#   b'(\\HasChildren \\Noselect) "/" "[Gmail]"',
#   b'(\\All \\HasNoChildren) "/" "[Gmail]/All Mail"',
#   b'(\\Drafts \\HasNoChildren) "/" "[Gmail]/Drafts"',
#   b'(\\HasNoChildren \\Important) "/" "[Gmail]/Important"',
#   b'(\\HasNoChildren \\Sent) "/" "[Gmail]/Sent Mail"',
#   b'(\\HasNoChildren \\Junk) "/" "[Gmail]/Spam"',
#   b'(\\Flagged \\HasNoChildren) "/" "[Gmail]/Starred"',
#   b'(\\HasNoChildren \\Trash) "/" "[Gmail]/Trash"'])

# %%
typ, data = M.search(None,'SUBJECT "Test Py Script"')

# %%
typ
# Out:
# 'OK'

# %%
email_id = data[0]

# %%
result, email_data = M.fetch(email_id,'(RFC822)')

# %%
email_data
# Out:
# [(b'2886 (RFC822 {602}',
#   b'Bcc: classmaterialsaiub@gmail.com\r\nReturn-Path: <classmaterialsaiub@gmail.com>\r\nReceived: from PG005085.paragon.com.bd ([119.148.56.202])\r\n        by smtp.gmail.com with ESMTPSA id a92af1059eb24-13fca9111b6sm215625c88.13.2026.08.04.00.17.53\r\n        for <classmaterialsaiub@gmail.com>\r\n        (version=TLS1_3 cipher=TLS_AES_256_GCM_SHA384 bits=256/256);\r\n        Tue, 04 Aug 2026 00:17:55 -0700 (PDT)\r\nMessage-ID: <6a719223.0f490953.111d61.d522@mx.google.com>\r\nDate: Tue, 04 Aug 2026 00:17:55 -0700 (PDT)\r\nFrom: classmaterialsaiub@gmail.com\r\nSubject: Test Py Script\r\n\r\nSending Email through PyScript\r\n'),
#  b')']

# %%
raw_email = email_data[0][1]

# %%
raw_email_string = raw_email.decode('utf-8')

# %%
email_message = email.message_from_string(raw_email_string)

# %%
for part in email_message.walk():
    if part.get_content_type() == 'text/plain':
        body = part.get_payload(decode=True)
        print(body)
# Out:
# b'Sending Email through PyScript\r\n'
