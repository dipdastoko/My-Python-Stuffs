# %%
d={'k1':1,'k2':2}

# %%
{x:x**2 for x in range(10)}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
{k:v**2 for k,v in zip(['a','b'],range(2))}
# Out:
# {'a': 0, 'b': 1}

# %%
for k in d.():
    print(k)
# Out:
# 1
# 2

# %%
l=[1,2,3]

# %%
l.append(4)

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
l.extend(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 l.extend(4)
#
# TypeError: 'int' object is not iterable

# %%
l.append([4,5])

# %%
l
# Out:
# [1, 2, 3, 4, [4, 5]]

# %%
l.extend([4,5])

# %%
l
# Out:
# [1, 2, 3, 4, [4, 5], 4, 5]

# %%
l.extend((6,7))

# %%
l
# Out:
# [1, 2, 3, 4, [4, 5], 4, 5, 6, 7]

# %%
l.insert(2,'Dip')

# %%
l
# Out:
# [1, 2, 'Dip', 3, 4, [4, 5], 4, 5, 6, 7]

# %%
l.pop(5)
# Out:
# [4, 5]

# %%
l
# Out:
# [1, 2, 'Dip', 3, 4, 4, 5, 6, 7]

# %%
l.remove('Dip')

# %%
l
# Out:
# [1, 2, 3, 4, 4, 5, 6, 7]

# %%
l.remove(4)

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
l.reverse()

# %%
l
# Out:
# [7, 6, 5, 4, 3, 2, 1]

# %%
l.sort()

# %%
l
