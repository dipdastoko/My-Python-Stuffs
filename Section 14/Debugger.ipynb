# %%
x = [1,2,3]
y=2
z=3

# %%
import pdb

# %%
x = [1,2,3]
y=2
z=3

# %%
result_one = y + z

pdb.set_trace()
result_two = y + x
# Out:
# > c:\users\dip.das\appdata\local\temp\ipykernel_7420\260705644.py(3)<module>()
# ipdb>  x
# [1, 2, 3]
# ipdb>  y
# 2
# ipdb>  x+y
# *** TypeError: can only concatenate list (not "int") to list
# ipdb>  ohh. okay. thanks
# *** NameError: name 'ohh' is not defined
