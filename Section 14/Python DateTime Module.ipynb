# %%
import datetime

# %%
mytime = datetime.time(2,5)

# %%
mytime.minute
# Out:
# 5

# %%
mytime.hour
# Out:
# 2

# %%
print(mytime)
# Out:
# 02:05:00

# %%
print(mytime)
# Out:
# 02:05:00

# %%
type(mytime)
# Out:
# datetime.time

# %%
today = datetime.date.today()

# %%
today.day
# Out:
# 22

# %%
today.year
# Out:
# 2026

# %%
today.month
# Out:
# 7

# %%
today.day
# Out:
# 22

# %%
today.ctime()
# Out:
# 'Wed Jul 22 00:00:00 2026'

# %%
from datetime import datetime

# %%
mydatetime = datetime(2026,7,22,9,43,10)

# %%
mydatetime
# Out:
# datetime.datetime(2026, 7, 22, 9, 43, 10)

# %%
print(mydatetime)
# Out:
# 2026-07-22 09:43:10

# %%
mydatetime = mydatetime.replace(year=2027)

# %%
print(mydatetime)
# Out:
# 2027-07-22 09:43:10

# %%
from datetime import date

# %%
date1=date(2021,11,3)
date2=date(2020,11,3)

# %%
result = date1 - date2

# %%
print(result)
# Out:
# 365 days, 0:00:00

# %%
result.days
# Out:
# 365
