# %%
from collections import Counter

# %%
mylist = [1,1,1,2,2,2,4,4,4,4]

# %%
Counter(mylist)
# Out:
# Counter({4: 4, 1: 3, 2: 3})

# %%
mylist=['a','b','b','a',1,1,12,12]

# %%
Counter(mylist)
# Out:
# Counter({'a': 2, 'b': 2, 1: 2, 12: 2})

# %%
Counter('aaabbbssfsdffwfw')
# Out:
# Counter({'f': 4, 'a': 3, 'b': 3, 's': 3, 'w': 2, 'd': 1})

# %%
letters='aaaabbbbccccccdddddddd'

# %%
c = Counter(letters)

# %%
c.most_common(2)
# Out:
# [('d', 8), ('c', 6)]

# %%
list(c)
# Out:
# ['a', 'b', 'c', 'd']

# %%
from collections import defaultdict

# %%
d={'a':10}

# %%
d['a']
# Out:
# 10

# %%
d = defaultdict(lambda: 0)

# %%
d['key1']=10

# %%
d['wrong key']
# Out:
# 0

# %%
d
# Out:
# defaultdict(<function __main__.<lambda>()>, {'key1': 10, 'wrong key': 0})

# %%
mytuple = (10,20,30)

# %%
mytuple[0]
# Out:
# 10

# %%
from collections import namedtuple

# %%
Dog = namedtuple('Dog',['age','breed','name'])

# %%
sammy = Dog(age=5,breed='Husky',name='Sam')

# %%
type(sammy)
# Out:
# __main__.Dog

# %%
sammy.name
# Out:
# 'Sam'

# %%
sammy[2]
# Out:
# 'Sam'
