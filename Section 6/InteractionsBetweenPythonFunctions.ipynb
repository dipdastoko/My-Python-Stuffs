# %%
example = [1,2,3,4,5,6,7]

# %%
from random import shuffle

# %%
shuffle(example)

# %%
example
# Out:
# [6, 5, 4, 2, 3, 1, 7]

# %%
def shuffle_list(mylist):
    shuffle(mylist)
    return mylist

# %%
def player_guess():
    guess=''

    while guess not in ['0','1','2']:
        guess = input('Pick a number: 0, 1 or 2. You choosen - ')

    return int(guess)

# %%
my_index = player_guess()
# Out:
# Pick a number: 0, 1 or 2. You choosen -  2

# %%
def check_guess(mylist,guess):
    if mylist[guess]=='O':
        print('Correct')
    else:
        print('Incorrect')
    print(mylist)

# %%
mylist = [' ','O',' ']
shuffle_list(mylist)
guess = player_guess()
check_guess(mylist,guess)
# Out:
# Pick a number: 0, 1 or 2. You choosen -  1
# Incorrect
# [' ', ' ', 'O']

# %%
strs='skjf'
strs[1:-1]
# Out:
# 'kj'

# %%
strs[-1]
# Out:
# 'f'
