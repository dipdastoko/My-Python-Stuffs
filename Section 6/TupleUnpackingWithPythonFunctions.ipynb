# %%
stock_prices = [("GOOG",200),("APPL",400),("MSFT",100)]

# %%
for item in stock_prices:
    print(item)
# Out:
# ('GOOG', 200)
# ('APPL', 400)
# ('MSFT', 100)

# %%
for ticker,price in stock_prices:
    print(ticker)
    print(price)
    print('\n')
# Out:
# GOOG
# 200
#
#
# APPL
# 400
#
#
# MSFT
# 100

# %%
work_hours = [("Abby",100),("Billy",400),("Cassie",800)]

# %%
def employee_check(work_hours):
    current_max = 0
    employee_of_month = ''

    for employee,hour in work_hours:
        if hour > current_max:
            current_max = hour
            employee_of_month = employee

    return (employee_of_month,current_max)

# %%
employee_check(work_hours)
# Out:
# ('Cassie', 800)

# %%
name, hour = employee_check(work_hours)
name
# Out:
# 'Cassie'

# %%
hour
# Out:
# 800
