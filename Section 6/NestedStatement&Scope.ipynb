# %%
x=25

# %%
def printer():
    x=50
    return x

# %%
print(x)
# Out:
# 25

# %%
print(printer())
# Out:
# 50

# %%
name = 'I am Global'
def greet():
    #name = 'I am Enclosing'
    def hello():
        #name = 'I am Local'
        print('Hi, ',name)
    hello()

# %%
greet()
# Out:
# Hi,  I am Global
