# %%
1<2>3
# Out:
# False

# %%
not 1==1
# Out:
# False

# %%
!(1==1)
# Out:
# '1' is not recognized as an internal or external command,
# operable program or batch file.

# %%
not(1==2)
# Out:
# True
