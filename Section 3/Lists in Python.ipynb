# %%
my_list = [1,2,3]

# %%
my_list = ['String',2,2.4]

# %%
len(my_list)
# Out:
# 3

# %%
my_list = ['one','two','three']

# %%
my_list[1:]
# Out:
# ['two', 'three']

# %%
my_list[2]
# Out:
# 'three'

# %%
another_list = ['Four','Five']

# %%
new_list=my_list+another_list

# %%
new_list
# Out:
# ['one', 'two', 'three', 'Four', 'Five']

# %%
new_list[0] = 'All Caps'

# %%
new_list
# Out:
# ['All Caps', 'two', 'three', 'Four', 'Five']

# %%
new_list.append('six')

# %%
new_list
# Out:
# ['All Caps', 'two', 'three', 'Four', 'Five', 'six']

# %%
new_list.pop()
# Out:
# 'six'

# %%
new_list
# Out:
# ['All Caps', 'two', 'three', 'Four', 'Five']

# %%
new_list.pop(0)
# Out:
# 'All Caps'

# %%
new_list
# Out:
# ['two', 'three', 'Four', 'Five']

# %%
new_list.pop(-1)
# Out:
# 'Five'

# %%
new_list
# Out:
# ['two', 'three', 'Four']

# %%
new_list = ['a','b','e','c','x']

# %%
num_list = [4,1,8,3]

# %%
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
num_list.sort()

# %%
num_list
# Out:
# [1, 3, 4, 8]

# %%
num_list.reverse()

# %%
num_list
# Out:
# [8, 4, 3, 1]
