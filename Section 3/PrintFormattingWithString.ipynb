# %%
"I am Dip {}".format('Das')
# Out:
# 'I am Dip Das'

# %%
"I am {0} {0} {0}".format('Das','Dip','Toko')
# Out:
# 'I am Das Das Das'

# %%
"I am {FirstName} {LastName} {NickName}".format(LastName="Das",FirstName='Dip',NickName='Toko')
# Out:
# 'I am Dip Das Toko'

# %%
print("The result was {f:1.3f}".format(f=200/700))
# Out:
# The result was 0.286
