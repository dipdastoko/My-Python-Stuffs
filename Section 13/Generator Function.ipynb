# %%
def create_cubes(n):
    for x in range(n):
        yield(x**3)

# %%
list(create_cubes(5))
# Out:
# [0, 1, 8, 27, 64]

# %%
for x in create_cubes(5):
    print(x)
# Out:
# 0
# 1
# 8
# 27
# 64

# %%
def gen_fibon(n):
    a=1
    b=1
    for i in range(n):
        yield a
        a,b=b,a+b
