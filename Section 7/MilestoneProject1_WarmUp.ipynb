# %%
row1=[' ',' ',' ']
row2=[' ',' ',' ']
row3=[' ',' ',' ']

# %%
def display(row1,row2,row3):
    print(row1)
    print(row3)
    print(row3)

# %%
display(row1,row2,row3)
# Out:
# [' ', ' ', ' ']
# [' ', ' ', ' ']
# [' ', ' ', ' ']

# %%
position_index = int(input("Choose a position"))
# Out:
# Choose a position 2

# %%
position_index
# Out:
# 2

# %%
def user_choice():
    choice = 'Wrong'
    acceptable_range=range(0,10)
    within_range = False
    
    while choice.isdigit() == False or within_range==False:
        choice = input("Please enter a number (0-10): ")
        
        if choice.isdigit() == False:
            print("Wrong choice. Please enter a numeric number")
            
        if choice.isdigit() == True:
            if int(choice) in acceptable_range:
                within_range=True
            else:
                print("Please choose the number between 1 to 10")
    return int(choice)

# %%
user_choice()
# Out:
# Please enter a number (0-10):  lksdjf
# Wrong choice. Please enter a numeric number
# Please enter a number (0-10):  48
# Please choose the number between 1 to 10
# Please enter a number (0-10):  5
# 5

# %%
game_list = [0,1,2]

# %%
def display_game(game_list):
    print("Here is the current list: ")
    print(game_list)

# %%
display_game(game_list)
# Out:
# Here is the current list:
# [0, 1, 2]

# %%
def position_choice():
    choice='wrong'
    while choice not in ['0','1','2']:
        choice = input("Pick a position (0,1,2): ")
        if choice not in ['0','1','2']:
            print("Sorry, Invalid Choice")
    return int(choice)

# %%
position_choice()
# Out:
# Pick a position (0,1,2):  lksdf
# Sorry, Invalid Choice
# Pick a position (0,1,2):  3
# Sorry, Invalid Choice
# Pick a position (0,1,2):  2
# 2

# %%
def replacement_choice(game_list,position):
    user_placement=input("Type a string to place at position: ")
    game_list[position] = user_placement

    return game_list

# %%
replacement_choice(game_list,1)
# Out:
# Type a string to place at position:  Dip
# [0, 'Dip', 2]

# %%
def gameon_choice():
    choice='wrong'
    while choice not in ['Y','N']:
        choice = input("Keep Playing: (Y or N) ")
        if choice not in ['Y','N']:
            print("Sorry, Please choose Y or N")
    if choice == "Y":
        return True
    else:
        return False

# %%
gameon_choice()
# Out:
# Keep Playing: (Y or N)  slkdf
# Sorry, Please choose Y or N
# Keep Playing: (Y or N)  Y
# True

# %%
game_on = True
game_list = [0,1,2]

while game_on:
    display_game(game_list)
    position = position_choice()
    gareplacement_choice(game_list,position)
