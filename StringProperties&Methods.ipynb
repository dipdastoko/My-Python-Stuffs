# %%
name = "Sam"

# %%
#name[0]="P"

# %%
lastLetters = name[1:]

# %%
lastLetters
# Out:
# 'am'

# %%
'P'+lastLetters
# Out:
# 'Pam'

# %%
'z'*10
# Out:
# 'zzzzzzzzzz'

# %%
x='Hello world'

# %%
x.upper()
# Out:
# 'HELLO WORLD'

# %%
x.lower()
# Out:
# 'hello world'

# %%
x.capitalize()
# Out:
# 'Hello world'
