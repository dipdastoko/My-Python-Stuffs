# %%
1+1
# Out:
# 2

# %% [markdown]
# sdfsad

# %%
print("Hello \tworld")
# Out:
# Hello 	world

# %%
len("Hello World")
# Out:
# 11

# %%
mystring = "Hello World"

# %%
mystring[0]
# Out:
# 'H'

# %%
mystring[8]
# Out:
# 'r'

# %%
mystring[-2]
# Out:
# 'l'

# %%
mystring[-3]
# Out:
# 'r'

# %%
mystring='abcdefghijk'

# %%
mystring[2:]
# Out:
# 'cdefghijk'

# %%
mystring[:3]
# Out:
# 'abc'

# %%
mystring[3:11]
# Out:
# 'defghijk'

# %%
mystring[::3]
# Out:
# 'adgj'

# %%
mystring[2:3:2]
# Out:
# 'c'

# %%
mystring[::-1]
# Out:
# 'kjihgfedcba'
